# %%
# %matplotlib notebook
#%matplotlib inline  #oly to show on jpyterlab, but not interactive

# %%
import pandas as pd
df = pd.read_csv('lnkd.csv', parse_dates=['Date'], index_col='Date')
df[['Close', 'Volume']].plot(subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f4decf0f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7f46a95dd8>],
#       dtype=object)
